# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path_1 = 'gdrive/My Drive/QW/Notebook/Quick Draw/Thesis_pre_research/(1-1)LastImg_Skatch-A-Net/Log_1_1(128).log'
path_2 = 'gdrive/My Drive/QW/Notebook/Quick Draw/Thesis_pre_research/(1-2)LastImg_MobileNet/Log_1_2.log'
path_3 = 'gdrive/My Drive/QW/Notebook/Quick Draw/Thesis_pre_research/(2-1)StrokeColor_Skatch-A-Net/Log_2_1.log'
path_4 = 'gdrive/My Drive/QW/Notebook/Quick Draw/Thesis_pre_research/(2-2)Stroke_MobileNet/Log_2_2.log'
path_5 = 'gdrive/My Drive/QW/Notebook/Quick Draw/Thesis_pre_research/(3-1)Stroke_LSTM-Skatch-A-Net/Log_3_1.log'
path_6 = 'gdrive/My Drive/QW/Notebook/Quick Draw/Thesis_pre_research/(3-2)Stroke_LSTM-MobileNet/Log_3_2.log'
marker = ['o','*','s',',','p','v']
name = ['LastImg_Skatch-A-Net','LastImg_MobileNet','StrokeColor_Skatch-A-Net','StrokeColor_MobileNet','Skatch-A-Net_LSTM','MobileNet_LSTM']
path = [path_1, path_2, path_3, path_4, path_5, path_6]
val_acc = []
plt.figure(figsize=(8,8),facecolor='white')
for i in range(6):
    temp_data = pd.read_csv(path[i])
    temp_val_acc = temp_data['val_acc'].values
    y = temp_val_acc 
    x = range(1,51)
    plt.plot(x,y,marker= marker[i],label=name[i],mew=0.01)
plt.legend()
plt.xlabel('epoch')
plt.ylabel('val_acc')
plt.savefig('gdrive/My Drive/QW/Notebook/Quick Draw/Thesis_pre_research/All_val_acc_plot.png')
plt.show()

# %%
path =  'gdrive/My Drive/QW/Notebook/Quick Draw/Thesis_pre_research/(3-2)Stroke_LSTM-MobileNet/Log_3_2.log'
data = pd.read_csv(path)
print(data)
# Out:
#     epoch       acc      loss  val_acc  val_loss
# 0       0  0.160365  4.141998   0.0025  7.479683
# 1       1  0.417047  2.490540   0.3524  3.088593
# 2       2  0.503871  2.079882   0.5035  2.132361
# 3       3  0.551847  1.846334   0.5059  2.141520
# 4       4  0.579882  1.720255   0.5506  1.965218
# 5       5  0.600576  1.624025   0.5889  1.759400
# 6       6  0.614518  1.567844   0.6054  1.676638
# 7       7  0.628929  1.508435   0.5773  1.757916
# 8       8  0.640024  1.455995   0.6363  1.476250
# 9       9  0.647388  1.420522   0.6340  1.530320
# 10     10  0.654824  1.394604   0.6382  1.492140
# 11     11  0.657671  1.370731   0.6442  1.465664
# 12     12  0.667024  1.337639   0.6521  1.421123
# 13     13  0.669635  1.331336   0.6709  1.338360
# 14     14  0.675624  1.301800   0.6792  1.302187
# 15     15  0.679200  1.285276   0.6842  1.295222
# 16     16  0.680624  1.275226   0.6871  1.249793
# 17     17  0.685447  1.252219   0.6933  1.224931
# ...

# %%
data.drop([0, 1, 2,3], inplace=True)
data.to_csv(path,index=False)
